# %%
import pandas as pd

# %%
data = pd.read_csv('ShopeeHerb.csv')

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                  Name  Price         Province  \
# 0   ฮัมเฮิร์บ พาวเวอร์ฟูล แอมพลู เซรั่ม AM HERB PO...    339        บุรีรัมย์
# 1   ♦️แถมฟรีดีท็อกซ์♦️ของแท้ส่งไว♦️เฮิร์บ​ HERB VI...     88    กรุงเทพมหานคร
# 2   G-HERB จี-เฮิร์บ จีเฮิร์บ แคปซูลวัน สมุนไพรบำร...    900    กรุงเทพมหานคร
# 3   [3 ขวด ราคาพิเศษ] THAI HERB เคอร์คูมิน โปร ผลิ...    900  พระนครศรีอยุธยา
# 4   DayHerb  แชมพูปิดผมขาว สมุนไพรแท้ ปิดหงอก ลดหง...    790          นนทบุรี
# 5   Me Herb Phlu Khao มีเฮิร์บ พลูคาว (30 แคปซูล/ก...    350         ปทุมธานี
# 6   G-HERB จีเฮิร์บ (โฉมใหม่) สมุนไพรบำรุงน้ำเหลือ...    900    กรุงเทพมหานคร
# 7          แชมพูปิดผมขาว DAYHERB แชมพูปิดผมขาวสมุนไพร    465    กรุงเทพมหานคร
# 8   G-HERB จี-เฮิร์บ จีเฮิร์บ แคปซูลวัน สมุนไพรบำร...    900    กรุงเทพมหานคร
# 9   น้ำเหลืองไม่ดี ภูมิแพ้ สะเก็ดเงิน แผลหายช้า  จ...    900       ฉะเชิงเทรา
# 10       Hi-Herb ยาสีฟัน สมุนไพร ไฮเฮิร์บ 3 สูตร ใหม่     68    กรุงเทพมหานคร
# 11  Hi-Herb ยาสีฟัน ไฮเฮิร์บ Premium Organic Care ...     89           ชลบุรี
# 12  #พร้อมส่ง ส่งไว  OK Herb (โอเค เฮิร์บ) กระชายข...     69        เชียงใหม่
# 13  ส่งฟรี!แชมพู Day Herb สีดำ/น้ำตาล/ไวน์แดง ปิดผ...    345    กรุงเทพมหานคร
# 14  Hi-Herb ยาสีฟัน ไฮเฮิร์บ Day & Night Care สูตร...    285           ชลบุรี
# 15        G-HERB จีเฮิร์บ สมุนไพรคุณหมอสมหมาย โฉมใหม่    900  ประจวบคีรีขันธ์
# 16            Salz ยาสีฟัน ซอลส์ King Herb 40,80 กรัม     50    กรุงเทพมหานคร
# 17          Green Apple Herb ดีท็อกแอปเปิ้ล [10 เม็ด]     10    กรุงเทพมหานคร
# 18  โกโก้ ไฟเบอร์ ชัวร์เฮิร์บ (โฉมใหม่) ขนาด 20 ซอ...    195          นนทบุรี
# 19  แท้100% Detox bherb Triphala tablet ตรีผลา 30เ...    109       ฉะเชิงเทรา
# 42  🧤พร้อมส่ง+ส่งฟรี | Korsé by herb คอร์เซ่ สมุนไ...    290             ตรัง
# 43  Day Care Herb Natural Shampoo แชมพูสมุนไพรปกปิ...    370         ร้อยเอ็ด
# 44  Queen Herb ควีน เฮิร์บ แชมพูอัญชัน + ทรีทเมนท์...    108      อุบลราชธานี
# 45  แพ็คคู่x2 ยาสีฟัน สมุนไพร บ้านพระอาทิตย์ 50 กร...    253    กรุงเทพมหานคร
# 46  Hi-Herb ยาสีฟัน ไฮเฮิร์บ Day & Night Care สูตร...     89           ชลบุรี
# 47                      ยาสีฟันทิสมาเฮิร์บ tisma herb     90    กรุงเทพมหานคร
# 48  JDENT 3IN1 Herbal White Toothpaste ยาสีฟันสมุน...     79         อุดรธานี
# 49  ส่งฟรี!! โปรโมชั่นขายดี Queen Herb แชมพูควีนเฮ...   1100           นครปฐม
# 50  ♦️แถมฟรีดีท็อกซ์♦️ของแท้ส่งไว♦️เฮิร์บ​ HERB VI...     88    กรุงเทพมหานคร
# 51  STAR HERB สตาร์ เฮิร์บ อาหารเสริม ใบบัวบก กิงโ...    499    กรุงเทพมหานคร
# 52  BSC Hi-Herb ยาสีฟัน สมุนไพร ไฮเฮิร์บ 3 สูตร ให...     65         สุรินทร์
# 53  HandyHerb(แฮนดี้เฮิร์บ) Night Night 12 ขวด แถม...    225          นนทบุรี
# 54  ส่งฟรี‼️ แชมพูควีนเฮิร์บ Queen Herb สูตรอ่อนโย...    390           นครปฐม
#
#     AmountSold
# 0            6
# 1       172500
# 2           25
# 3           35
# 4         5600
# 5           52
# 6           34
# 7         1400
# 8           25
# 9          103
# 10        2100
# 11         322
# 12           5
# 13         648
# 14         236
# 15          17
# 16           4
# 17           4
# 18          13
# 19        2000
# 20          59
# 21         178
# 22         679
# 23         179
# 24          11
# 25          53
# 26          57
# 27       24200
# 28        3900
# 29         126
# 30         764
# 31          34
# 32          21
# 33         397
# 34         254
# 35         114
# 36          13
# 37        3900
# 38         496
# 39        1000
# 40         727
# 41          10
# 42         253
# 43         338
# 44         541
# 45         865
# 46         238
# 47        1500
# 48         529
# 49         581
# 50      172500
# 51          27
# 52         134
# 53          36
# 54        5800

# %%
df.to_json('shopee.json')

# %%
from dsmlibrary.datanode import DataNode

# %%
dir_raw_id = 70

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
datanode.upload_file(directory_id=dir_raw_id, file_path='shopee.json')
# Out:
#   0%|          | 0.00/21.9k [00:00<?, ?B/s]
# {'id': 695,
#  'msg': 'file shopee.json create sucessful',
#  'path': 'kitipop/DSI310-19/rawData/shopee.json',
#  'uploaded': True}
